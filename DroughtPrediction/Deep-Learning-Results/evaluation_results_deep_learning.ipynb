# %% [markdown]
# In this notebook, we evaluate the results of all deep learning models.

# %% [markdown]
# # Import packages

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef

# %% [markdown]
# # Define the function to plot confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
matplotlib.rcParams['font.size'] = 20

# %%
def plot_cm(y_true, y_pred, save_fn):
    label_mapping = {0: 'No Drought', 1: 'D0', 2: 'D1', 3: 'D2', 4: 'D3', 5: 'D4'}
    labels = ['No Drought', 'D0', 'D1', 'D2', 'D3', 'D4']
    y_true_to_plot = [label_mapping[i] for i in y_true]
    y_pred_to_plot = [label_mapping[i] for i in y_pred]

    data = confusion_matrix(y_true_to_plot, y_pred_to_plot, labels= labels)
    df_cm = pd.DataFrame(data, columns=labels, index = labels)
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    plt.figure(figsize = (12, 9))
    # sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, cmap="Blues", annot=True, fmt='d', annot_kws={"size": 22})  # font size
    plt.savefig(save_fn, dpi=400, bbox_inches='tight')

# %% [markdown]
# # Evaluate the saved predictions

# %%
results = {}

# %%
model = 'MLP'

true_values = np.load('y_true_MLP.npy')
pred_values = np.load('y_pred_MLP.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'RNN'

true_values = np.load('y_true_RNN.npy')
pred_values = np.load('y_pred_RNN.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'GRU'

true_values = np.load('y_true_GRU.npy')
pred_values = np.load('y_pred_GRU.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'LSTM'

true_values = np.load('y_true_LSTM.npy')
pred_values = np.load('y_pred_LSTM.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'FCN'

true_values = np.load('y_true_FCN.npy')
pred_values = np.load('y_pred_FCN.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'ResNet'

true_values = np.load('y_true_ResNet.npy')
pred_values = np.load('y_pred_ResNet.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'ResCNN'

true_values = np.load('y_true_ResCNN.npy')
pred_values = np.load('y_pred_ResCNN.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'TCN'

true_values = np.load('y_true_TCN.npy')
pred_values = np.load('y_pred_TCN.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'InceptionTime'

true_values = np.load('y_true_InceptionTime.npy')
pred_values = np.load('y_pred_InceptionTime.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'XceptionTime'

true_values = np.load('y_true_XceptionTime.npy')
pred_values = np.load('y_pred_XceptionTime.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'OS-CNN'

true_values = np.load('y_true_OmniScaleCNN.npy')
pred_values = np.load('y_pred_OmniScaleCNN.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'XCM'

true_values = np.load('y_true_XCM.npy')
pred_values = np.load('y_pred_XCM.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'RNN_FCN'

true_values = np.load('y_true_RNN_FCN.npy')
pred_values = np.load('y_pred_RNN_FCN.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'GRU_FCN'

true_values = np.load('y_true_GRU_FCN.npy')
pred_values = np.load('y_pred_GRU_FCN.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'LSTM_FCN'

true_values = np.load('y_true_LSTM_FCN.npy')
pred_values = np.load('y_pred_LSTM_FCN.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'TST'

true_values = np.load('y_true_TST.npy')
pred_values = np.load('y_pred_TST.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
df = pd.DataFrame(results)
df = df.T

# %%
df.head(20)
# Out:
#                Accuracy  Precision    Recall  F1 Score       MCC
# MLP            0.710954   0.283828  0.277677  0.276589  0.302546
# RNN            0.730060   0.343868  0.238140  0.244872  0.262650
# GRU            0.732666   0.326380  0.267004  0.280845  0.311890
# LSTM           0.719799   0.327343  0.293589  0.302211  0.320123
# FCN            0.710768   0.345344  0.282706  0.290754  0.313561
# ResNet         0.724671   0.291364  0.232957  0.243958  0.254368
# ResCNN         0.726848   0.297748  0.228978  0.238480  0.251923
# TCN            0.703856   0.323455  0.289654  0.297582  0.307020
# InceptionTime  0.729689   0.315999  0.253339  0.261491  0.300348
# XceptionTime   0.725178   0.338632  0.282120  0.298022  0.322493
# OS-CNN         0.730177   0.300573  0.248306  0.261392  0.282678
# XCM            0.710153   0.319508  0.273493  0.286139  0.295595
# RNN_FCN        0.702734   0.330452  0.290090  0.296878  0.316673
# GRU_FCN        0.720658   0.308223  0.269361  0.281426  0.293630
# LSTM_FCN       0.723977   0.317334  0.263957  0.276769  0.295149
# TST            0.729503   0.313479  0.261155  0.273483  0.299191

# %%
stats = {}
stats['Max'] = {}
stats['Mean'] = {}
stats['Std'] = {}

columns = df.columns

for col in columns:
    stats['Mean'][col] = df.loc[:, col].mean()
    stats['Max'][col] = df.loc[:, col].max()
    stats['Std'][col] = df.loc[:, col].std()

# %%
df_stats = pd.DataFrame(stats)
df_stats = df_stats.T
df = pd.concat([df, df_stats])

# %%
df.head(30)
# Out:
#                Accuracy  Precision    Recall  F1 Score       MCC
# MLP            0.710954   0.283828  0.277677  0.276589  0.302546
# RNN            0.730060   0.343868  0.238140  0.244872  0.262650
# GRU            0.732666   0.326380  0.267004  0.280845  0.311890
# LSTM           0.719799   0.327343  0.293589  0.302211  0.320123
# FCN            0.710768   0.345344  0.282706  0.290754  0.313561
# ResNet         0.724671   0.291364  0.232957  0.243958  0.254368
# ResCNN         0.726848   0.297748  0.228978  0.238480  0.251923
# TCN            0.703856   0.323455  0.289654  0.297582  0.307020
# InceptionTime  0.729689   0.315999  0.253339  0.261491  0.300348
# XceptionTime   0.725178   0.338632  0.282120  0.298022  0.322493
# OS-CNN         0.730177   0.300573  0.248306  0.261392  0.282678
# XCM            0.710153   0.319508  0.273493  0.286139  0.295595
# RNN_FCN        0.702734   0.330452  0.290090  0.296878  0.316673
# GRU_FCN        0.720658   0.308223  0.269361  0.281426  0.293630
# LSTM_FCN       0.723977   0.317334  0.263957  0.276769  0.295149
# TST            0.729503   0.313479  0.261155  0.273483  0.299191
# Max            0.732666   0.345344  0.293589  0.302211  0.322493
# Mean           0.720731   0.317721  0.265783  0.275681  0.295615
# Std            0.009918   0.018069  0.020630  0.020461  0.022264
