# %% [markdown]
# In this notebook, we evaluate the results of all machine learning models.

# %% [markdown]
# # Import packages

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef

# %% [markdown]
# # Define the function to plot confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
matplotlib.rcParams['font.size'] = 20

# %%
def plot_cm(y_true, y_pred, save_fn):
    label_mapping = {0: 'No Drought', 1: 'D0', 2: 'D1', 3: 'D2', 4: 'D3', 5: 'D4'}
    labels = ['No Drought', 'D0', 'D1', 'D2', 'D3', 'D4']
    y_true_to_plot = [label_mapping[i] for i in y_true]
    y_pred_to_plot = [label_mapping[i] for i in y_pred]

    data = confusion_matrix(y_true_to_plot, y_pred_to_plot, labels= labels)
    df_cm = pd.DataFrame(data, columns=labels, index = labels)
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    plt.figure(figsize = (12, 9))
    # sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, cmap="Blues", annot=True, fmt='d', annot_kws={"size": 22})  # font size
    plt.savefig(save_fn, dpi=400, bbox_inches='tight')

# %% [markdown]
# # Evaluate the saved predictions

# %%
results = {}

# %%
model = 'LR'

true_values = np.load('y_true_lr.npy')
pred_values = np.load('y_pred_lr.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'kNN'

true_values = np.load('y_true_knn.npy')
pred_values = np.load('y_pred_knn.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'NB'

true_values = np.load('y_true_nb.npy')
pred_values = np.load('y_pred_nb.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'SVM (linear)'

true_values = np.load('y_true_svm.npy')
pred_values = np.load('y_pred_svm.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'SVM (rbf)'

true_values = np.load('y_true_rbfsvm.npy')
pred_values = np.load('y_pred_rbfsvm.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'LDA'

true_values = np.load('y_true_lda.npy')
pred_values = np.load('y_pred_lda.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'QDA'

true_values = np.load('y_true_qda.npy')
pred_values = np.load('y_pred_qda.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'Ridge'

true_values = np.load('y_true_ridge.npy')
pred_values = np.load('y_pred_ridge.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'DT'

true_values = np.load('y_true_dt.npy')
pred_values = np.load('y_pred_dt.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'RF'

true_values = np.load('y_true_rf.npy')
pred_values = np.load('y_pred_rf.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'ET'

true_values = np.load('y_true_et.npy')
pred_values = np.load('y_pred_et.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'AdaBoost'

true_values = np.load('y_true_ada.npy')
pred_values = np.load('y_pred_ada.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'GB'

true_values = np.load('y_true_gbc.npy')
pred_values = np.load('y_pred_gbc.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'XGboost'

true_values = np.load('y_true_xgboost.npy')
pred_values = np.load('y_pred_xgboost.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'LightGBM'

true_values = np.load('y_true_lightgbm.npy')
pred_values = np.load('y_pred_lightgbm.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
model = 'CatBoost'

true_values = np.load('y_true_catboost.npy')
pred_values = np.load('y_pred_catboost.npy')

results[model] = {
    'Accuracy': accuracy_score(true_values, pred_values),
    'Precision': precision_score(true_values, pred_values, average='macro'),
    'Recall': recall_score(true_values, pred_values, average='macro'),
    'F1 Score': f1_score(true_values, pred_values, average='macro'),
    'MCC': matthews_corrcoef(true_values, pred_values)
}

# %%
plot_cm(true_values, pred_values, model + '.png')

# %%
df = pd.DataFrame(results)
df = df.T

# %%
df.head(20)
# Out:
#               Accuracy  Precision    Recall  F1 Score       MCC
# LR            0.715396   0.272493  0.248300  0.254582  0.269519
# kNN           0.564093   0.216749  0.215997  0.214940  0.096938
# NB            0.448677   0.234802  0.236588  0.193191  0.154372
# SVM (linear)  0.728527   0.226200  0.192162  0.177950  0.182705
# SVM (rbf)     0.616587   0.283164  0.307549  0.284406  0.297832
# LDA           0.720365   0.285301  0.254494  0.259070  0.258449
# QDA           0.726350   0.179616  0.166903  0.141142  0.014155
# Ridge         0.726184   0.268185  0.195487  0.194748  0.192315
# DT            0.723802   0.150001  0.173103  0.152947  0.074963
# RF            0.727424   0.217601  0.170410  0.147854  0.055681
# ET            0.726857   0.158222  0.166810  0.140648  0.012790
# AdaBoost      0.726086   0.269975  0.195044  0.187411  0.119844
# GB            0.726281   0.281126  0.222876  0.231897  0.230197
# XGboost       0.730567   0.278525  0.200447  0.202209  0.201698
# ...

# %%
stats = {}
stats['Max'] = {}
stats['Mean'] = {}
stats['Std'] = {}

columns = df.columns

for col in columns:
    stats['Mean'][col] = df.loc[:, col].mean()
    stats['Max'][col] = df.loc[:, col].max()
    stats['Std'][col] = df.loc[:, col].std()

# %%
df_stats = pd.DataFrame(stats)
df_stats = df_stats.T
df = pd.concat([df, df_stats])

# %%
df.head(30)
# Out:
#               Accuracy  Precision    Recall  F1 Score       MCC
# LR            0.715396   0.272493  0.248300  0.254582  0.269519
# kNN           0.564093   0.216749  0.215997  0.214940  0.096938
# NB            0.448677   0.234802  0.236588  0.193191  0.154372
# SVM (linear)  0.728527   0.226200  0.192162  0.177950  0.182705
# SVM (rbf)     0.616587   0.283164  0.307549  0.284406  0.297832
# LDA           0.720365   0.285301  0.254494  0.259070  0.258449
# QDA           0.726350   0.179616  0.166903  0.141142  0.014155
# Ridge         0.726184   0.268185  0.195487  0.194748  0.192315
# DT            0.723802   0.150001  0.173103  0.152947  0.074963
# RF            0.727424   0.217601  0.170410  0.147854  0.055681
# ET            0.726857   0.158222  0.166810  0.140648  0.012790
# AdaBoost      0.726086   0.269975  0.195044  0.187411  0.119844
# GB            0.726281   0.281126  0.222876  0.231897  0.230197
# XGboost       0.730567   0.278525  0.200447  0.202209  0.201698
# ...
